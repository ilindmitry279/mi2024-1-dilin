# %% [markdown]
# ## Тема 2. Заняття 2.  Методи збору даних для ІАЗ ОУВ
# ### 1. Основи збору даних через мережу Internet.

# %% [markdown]
# ##### Вступ
# Збір даних через Інтернет є однією з ключових складових інформаційно-аналітичного забезпечення (ІАЗ) органів управління військами (ОУВ). Інтернет надає доступ до величезних обсягів інформації, які можуть бути корисними для аналізу та підтримки прийняття рішень в оперативних і стратегічних умовах. У військовому контексті, цей процес охоплює як відкриті джерела (OSINT — Open Source Intelligence), так і різні методи моніторингу, аналізу й обробки даних.
#
# ##### Основні джерела даних з Інтернету
# 1. **Відкриті джерела інформації (OSINT)**:
#    - **ЗМІ (News Media)**: Аналіз статей, новин, блогів, онлайн-публікацій дає змогу отримувати оперативну інформацію про події, військові операції, соціально-політичні зміни.
#    - **Соціальні мережі (Social Media Intelligence, SOCMINT)**: Моніторинг соціальних мереж, таких як Twitter, Facebook, YouTube, дає можливість відслідковувати настрої, взаємодії, місця перебування, а також виявляти дезінформацію або пропаганду.
#    - **Геопросторові дані (GEOINT)**: Супутникові знімки, дані картографічних сервісів, таких як Google Maps або OpenStreetMap, використовуються для аналізу місцевості, переміщення військових сил та інфраструктури.
#
# 2. **Технологічні інструменти для збору даних**:
#    - **Веб-скрейпінг (Web Scraping)**: Збір даних з відкритих вебсайтів за допомогою автоматизованих інструментів (наприклад, Python з бібліотеками BeautifulSoup або Scrapy). Цей метод дозволяє отримати великі масиви даних з різних джерел, таких як публічні бази даних, новинні сайти та урядові ресурси.
#    - **Методики моніторингу соціальних мереж**: Спеціалізовані інструменти для моніторингу соціальних мереж (наприклад, Hootsuite, Meltwater, Brandwatch) дозволяють відслідковувати тренди, ключові слова та аналізувати вміст у реальному часі.
#
# 3. **Інструменти для аналізу великих обсягів даних**:
#    - **Big Data аналітика**: Використання аналітичних платформ для обробки великих даних, таких як Apache Hadoop або Spark, дозволяє ефективно аналізувати дані з різних джерел.
#    - **Штучний інтелект (AI) і машинне навчання (ML)**: Використовуються для автоматизації аналізу даних, виявлення шаблонів і прогнозування загроз на основі історичних даних.
#
# ##### Виклики та ризики збору даних через Інтернет
# - **Інформаційне перевантаження**: Великий обсяг інформації може ускладнювати її ефективну обробку та аналіз. Необхідно розробити методики фільтрації даних для виділення релевантної інформації.
# - **Вірогідність дезінформації**: В Інтернеті існує значна кількість фальшивих новин та дезінформаційних кампаній. Важливо забезпечити перевірку джерел і достовірність отриманих даних.
# - **Захист персональних даних та безпека**: Збір даних з Інтернету повинен проводитися з урахуванням правових і етичних норм, щоб уникнути порушення конфіденційності та безпеки.
#
# ##### Висновок
# Збір даних через Інтернет є важливою складовою сучасного ІАЗ ОУВ. Військові аналітики повинні володіти навичками використання технологій для збору та обробки даних з різних відкритих джерел, а також мати можливість оцінювати надійність і актуальність отриманої інформації.
#
# Цей матеріал допоможе студентам зрозуміти основи збору даних через Інтернет та їх використання для ефективного інформаційно-аналітичного забезпечення у військовому контексті.

# %% [markdown]
# Ось приклад коду на Python для **web scraping** з використанням бібліотеки `BeautifulSoup` та `requests` для збору даних із вебсайту:
#
# ```python
# import requests
# from bs4 import BeautifulSoup
#
# # URL сайту, з якого будемо збирати дані
# url = "https://example.com"
#
# # Використання requests для отримання HTML-коду сторінки
# response = requests.get(url)
#
# # Перевіряємо статус запиту
# if response.status_code == 200:
#     # Створюємо об'єкт BeautifulSoup для аналізу HTML
#     soup = BeautifulSoup(response.text, 'html.parser')
#
#     # Приклад: витягаємо всі заголовки (теги <h1>, <h2>, <h3> тощо)
#     headers = soup.find_all(['h1', 'h2', 'h3'])
#
#     # Виводимо знайдені заголовки
#     for header in headers:
#         print(header.text.strip())
#
# else:
#     print(f"Failed to retrieve data. HTTP Status code: {response.status_code}")
# ```
#
# ### Пояснення:
# 1. **requests.get()** — надсилає запит до вебсайту і отримує HTML-код сторінки.
# 2. **BeautifulSoup()** — створює об'єкт для аналізу HTML-коду.
# 3. **soup.find_all()** — шукає всі заголовки (`<h1>`, `<h2>`, `<h3>`) на сторінці та витягує їх текстовий вміст.
# 4. **strip()** — очищує текст від зайвих пробілів.
#
# ### Вимоги:
# 1. Встановіть бібліотеки, якщо вони ще не інстальовані:
#    ```bash
#    pip install requests beautifulsoup4
#    ```
#
# Цей код є простим прикладом для збору текстових даних із заголовків на вебсайті. Його можна модифікувати для збору інших елементів сторінки або аналізу специфічних структур даних.

# %%
import requests
from bs4 import BeautifulSoup

# URL сайту, з якого будемо збирати дані
url = "https://nuou.org.ua/u/"

# Використання requests для отримання HTML-коду сторінки
response = requests.get(url)

# Перевіряємо статус запиту
if response.status_code == 200:
    # Створюємо об'єкт BeautifulSoup для аналізу HTML
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # # Приклад: витягаємо всі заголовки та посилання (теги <h1>, <h2>, <h3>, <a> тощо)
    # tags = soup.find_all(['a'])

    # # усі посилання
    # links = [tag.get("href") for tag in tags if tag.get("href")]

    # print(links)
    pairs = [(tag.get_text(strip=True), tag.get("href")) 
         for tag in soup.find_all("a") if tag.get("href")]

    for name, link in pairs:
        print(name, "->", link)


    # Виводимо знайдені заголовки
    # for header in headers:
    #     print(header.text.strip())

else:
    print(f"Failed to retrieve data. HTTP Status code: {response.status_code}")
# Out:
# adl.mil.gov.ua -> https://adl.mil.gov.ua/
# adl.nuou.org.ua -> https://adl.nuou.org.ua/
# Головна -> /
# Акредитація -> u/accreditation.html
# Загальні відомості -> u/zv.html
# Керівництво -> u/ku.html
# Новини -> u/news/
# Статут -> u/statut-unversitetu.html
# Оголошення -> u/ogo/
# Структурні підрозділи -> u/stru/
# Документи -> u/dokumenti/
# Міжнародне співробітництво -> u/ms.html
# Кошторис університету -> u/fin-plan.html
# Фінансова звітність -> u/financial-report.html
# Запобігання корупції -> u/zap-kor.html
# Анонси подій -> u/ap/
# Профспілкова організація -> u/pfso.html
# Державні закупівлі -> u/deza.html
# Робота з громадянами -> u/robota-z-gromadyanami.html
# Очищення влади -> u/o-vladi.html
# Академічна доброчесність -> u/akademchna-dobrochesnst.html
# Музей -> u/stru/others/muzei/
# Опитування -> u/survey.html
# Репозиторій кваліфікаційних робіт -> u/repo-kval-rob.html
# Освіта -> osvita/
# Концепція освітньої діяльності -> osvita/kod.html
# Освітні проєкти -> osvita/op.html
# Вступникам -> osvita/vstupnikam.html
# Слухачам -> osvita/sluxacham.html
# Курсантам -> osvita/kursantam.html
# Студентам -> u/stru/centers/kvp/
# Лідерські курси -> osvita/leadership-courses.html
# Редакційно-видавнича діяльність -> osvita/rvv.html
# Наука -> nauka/
# Робота спеціалізованих вчених рад -> nauka/svr/
# Вступникам до докторантури та ад’юнктури -> nauka/vda.html
# Докторантам, ад’юнктам -> nauka/doktorantam-adyunktam.html
# Наукові публікації -> nauka/npub/
# Конференції та семінари -> nauka/confi/
# Наукові товариства -> nauka/ntov.html
# Угоди та меморандуми про співробітництво -> nauka/memo-cooperation.html
# Рада молодих вчених -> nauka/rada-molodyh-vchenyh.html
# Освітньо-наукові програми підготовки здобувачів ступеня доктора філософії -> nauka/osv-nauk-programy.html
# Доступ до наукометричних баз та повнотекстових наукових ресурсів -> nauka/dostup-do-baz-ta-resursiv.html
# Доступ до Національної електронної науково-інформаційної системи NAUKA -> nauka/dostup-nat-ele-nau-inf-sys.html
# Контакти -> contacts.html
#  -> https://www.facebook.com/TheNationalDefenseUniversity.ua/
#  -> https://www.youtube.com/channel/UCUavXkPHcrgIEFOayEOtL8Q
# Головна -> /
# Акредитація -> u/accreditation.html
# Загальні відомості -> u/zv.html
# Керівництво -> u/ku.html
# Новини -> u/news/
# Статут -> u/statut-unversitetu.html
# Оголошення -> u/ogo/
# Структурні підрозділи -> u/stru/
# Документи -> u/dokumenti/
# Міжнародне співробітництво -> u/ms.html
# Кошторис університету -> u/fin-plan.html
# Фінансова звітність -> u/financial-report.html
# Запобігання корупції -> u/zap-kor.html
# Анонси подій -> u/ap/
# Профспілкова організація -> u/pfso.html
# Державні закупівлі -> u/deza.html
# Робота з громадянами -> u/robota-z-gromadyanami.html
# Очищення влади -> u/o-vladi.html
# Академічна доброчесність -> u/akademchna-dobrochesnst.html
# Музей -> u/stru/others/muzei/
# Опитування -> u/survey.html
# Репозиторій кваліфікаційних робіт -> u/repo-kval-rob.html
# Освіта -> osvita/
# Концепція освітньої діяльності -> osvita/kod.html
# Освітні проєкти -> osvita/op.html
# Вступникам -> osvita/vstupnikam.html
# Слухачам -> osvita/sluxacham.html
# Курсантам -> osvita/kursantam.html
# Студентам -> u/stru/centers/kvp/
# Лідерські курси -> osvita/leadership-courses.html
# Редакційно-видавнича діяльність -> osvita/rvv.html
# Наука -> nauka/
# Робота спеціалізованих вчених рад -> nauka/svr/
# Вступникам до докторантури та ад’юнктури -> nauka/vda.html
# Докторантам, ад’юнктам -> nauka/doktorantam-adyunktam.html
# Наукові публікації -> nauka/npub/
# Конференції та семінари -> nauka/confi/
# Наукові товариства -> nauka/ntov.html
# Угоди та меморандуми про співробітництво -> nauka/memo-cooperation.html
# Рада молодих вчених -> nauka/rada-molodyh-vchenyh.html
# Освітньо-наукові програми підготовки здобувачів ступеня доктора філософії -> nauka/osv-nauk-programy.html
# Доступ до наукометричних баз та повнотекстових наукових ресурсів -> nauka/dostup-do-baz-ta-resursiv.html
# Доступ до Національної електронної науково-інформаційної системи NAUKA -> nauka/dostup-nat-ele-nau-inf-sys.html
# Контакти -> contacts.html
#  -> https://www.facebook.com/TheNationalDefenseUniversity.ua/
#  -> https://www.youtube.com/channel/UCUavXkPHcrgIEFOayEOtL8Q
#  -> https://nuou.org.ua/
#  -> https://nuou.org.ua/
# Головна -> /
# Акредитація -> u/accreditation.html
# Загальні відомості -> u/zv.html
# Керівництво -> u/ku.html
# Новини -> u/news/
# Статут -> u/statut-unversitetu.html
# Оголошення -> u/ogo/
# Структурні підрозділи -> u/stru/
# Документи -> u/dokumenti/
# Міжнародне співробітництво -> u/ms.html
# Кошторис університету -> u/fin-plan.html
# Фінансова звітність -> u/financial-report.html
# Запобігання корупції -> u/zap-kor.html
# Анонси подій -> u/ap/
# Профспілкова організація -> u/pfso.html
# Державні закупівлі -> u/deza.html
# Робота з громадянами -> u/robota-z-gromadyanami.html
# Очищення влади -> u/o-vladi.html
# Академічна доброчесність -> u/akademchna-dobrochesnst.html
# Музей -> u/stru/others/muzei/
# Опитування -> u/survey.html
# Репозиторій кваліфікаційних робіт -> u/repo-kval-rob.html
# Освіта -> osvita/
# Концепція освітньої діяльності -> osvita/kod.html
# Освітні проєкти -> osvita/op.html
# Вступникам -> osvita/vstupnikam.html
# Слухачам -> osvita/sluxacham.html
# Курсантам -> osvita/kursantam.html
# Студентам -> u/stru/centers/kvp/
# Лідерські курси -> osvita/leadership-courses.html
# Редакційно-видавнича діяльність -> osvita/rvv.html
# Наука -> nauka/
# Робота спеціалізованих вчених рад -> nauka/svr/
# Вступникам до докторантури та ад’юнктури -> nauka/vda.html
# Докторантам, ад’юнктам -> nauka/doktorantam-adyunktam.html
# Наукові публікації -> nauka/npub/
# Конференції та семінари -> nauka/confi/
# Наукові товариства -> nauka/ntov.html
# Угоди та меморандуми про співробітництво -> nauka/memo-cooperation.html
# Рада молодих вчених -> nauka/rada-molodyh-vchenyh.html
# Освітньо-наукові програми підготовки здобувачів ступеня доктора філософії -> nauka/osv-nauk-programy.html
# Доступ до наукометричних баз та повнотекстових наукових ресурсів -> nauka/dostup-do-baz-ta-resursiv.html
# Доступ до Національної електронної науково-інформаційної системи NAUKA -> nauka/dostup-nat-ele-nau-inf-sys.html
# Контакти -> contacts.html
# Головна -> /
# Національний -> http://zakon2.rada.gov.ua/laws/show/377/99
# Привітання начальника національного університету оборони України з Днем воєнної розвідки України -> u/news/privtannya-nachalnika-unversitetu-oboroni-z-dnem-rozvydky.html
#  -> u/news/privtannya-nachalnika-unversitetu-oboroni-z-dnem-rozvydky.html
# Детальніше -> u/news/privtannya-nachalnika-unversitetu-oboroni-z-dnem-rozvydky.html
# «Середньовічна людина крізь призму софійських графіті» — у Національному університеті оборони України презентована виставка — символ культурної спадкоємності та історичної неперервності -> u/news/vidkryttia-vystavky.html
#  -> u/news/vidkryttia-vystavky.html
# Детальніше -> u/news/vidkryttia-vystavky.html
# Привітання Начальника Національного університету оборони України з початком нового 2025–2026 навчального року -> u/news/privtannya-nachalnika-oboroni-ukrani-z-pochat.html
#  -> u/news/privtannya-nachalnika-oboroni-ukrani-z-pochat.html
# Детальніше -> u/news/privtannya-nachalnika-oboroni-ukrani-z-pochat.html
# Привітання начальника Національного університету оборони України з Днем авіації -> u/news/privtannya-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-a.html
#  -> u/news/privtannya-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-a.html
# Детальніше -> u/news/privtannya-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-a.html
# 29 серпня — День пам'яті захисників України, які загинули в боротьбі за незалежність, суверенітет і територіальну цілісність України -> u/news/serpnya-den-pamyat-zaxisnikv-ukrani,-yak-zaginuli-v-borotb-za-nezal.html
#  -> u/news/serpnya-den-pamyat-zaxisnikv-ukrani,-yak-zaginuli-v-borotb-za-nezal.html
# Детальніше -> u/news/serpnya-den-pamyat-zaxisnikv-ukrani,-yak-zaginuli-v-borotb-za-nezal.html
# Привітання начальника Національного університету оборони України з Днем Незалежності України -> u/news/nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-n.html
#  -> u/news/nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-n.html
# Детальніше -> u/news/nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-n.html
# 2 -> u/?page=2
# 3 -> u/?page=3
# 4 -> u/?page=4
# 5 -> u/?page=5
#  -> u/?page=2
#  -> u/?page=7
# Привітання начальника національного університету оборони України з Днем воєнної розвідки України -> u/news/privtannya-nachalnika-unversitetu-oboroni-z-dnem-rozvydky.html
#  -> u/news/privtannya-nachalnika-unversitetu-oboroni-z-dnem-rozvydky.html
# Детальніше -> u/news/privtannya-nachalnika-unversitetu-oboroni-z-dnem-rozvydky.html
# «Середньовічна людина крізь призму софійських графіті» — у Національному університеті оборони України презентована виставка — символ культурної спадкоємності та історичної неперервності -> u/news/vidkryttia-vystavky.html
#  -> u/news/vidkryttia-vystavky.html
# Детальніше -> u/news/vidkryttia-vystavky.html
# Привітання Начальника Національного університету оборони України з початком нового 2025–2026 навчального року -> u/news/privtannya-nachalnika-oboroni-ukrani-z-pochat.html
#  -> u/news/privtannya-nachalnika-oboroni-ukrani-z-pochat.html
# Детальніше -> u/news/privtannya-nachalnika-oboroni-ukrani-z-pochat.html
# Привітання начальника Національного університету оборони України з Днем авіації -> u/news/privtannya-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-a.html
#  -> u/news/privtannya-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-a.html
# Детальніше -> u/news/privtannya-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-a.html
# 29 серпня — День пам'яті захисників України, які загинули в боротьбі за незалежність, суверенітет і територіальну цілісність України -> u/news/serpnya-den-pamyat-zaxisnikv-ukrani,-yak-zaginuli-v-borotb-za-nezal.html
#  -> u/news/serpnya-den-pamyat-zaxisnikv-ukrani,-yak-zaginuli-v-borotb-za-nezal.html
# Детальніше -> u/news/serpnya-den-pamyat-zaxisnikv-ukrani,-yak-zaginuli-v-borotb-za-nezal.html
# Привітання начальника Національного університету оборони України з Днем Незалежності України -> u/news/nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-n.html
#  -> u/news/nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-n.html
# Детальніше -> u/news/nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-n.html
# Привітання начальника Національного університету оборони України з Днем Державного Прапора України -> u/news/nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-d.html
#  -> u/news/nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-d.html
# Детальніше -> u/news/nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-dnem-d.html
# Увага! Національний університет оборони України інформує! -> u/news/uvaga!-naczonalnij-unversitet-oboroni-ukrani-nformu.html
#  -> u/news/uvaga!-naczonalnij-unversitet-oboroni-ukrani-nformu.html
# Детальніше -> u/news/uvaga!-naczonalnij-unversitet-oboroni-ukrani-nformu.html
# Привітання начальника Національного університету оборони України з Днем військ зв'язку -> u/news/privtannya-nachalnika-unversitetu-oboroni-ukrani-z-dnem-v.html
#  -> u/news/privtannya-nachalnika-unversitetu-oboroni-ukrani-z-dnem-v.html
# Детальніше -> u/news/privtannya-nachalnika-unversitetu-oboroni-ukrani-z-dnem-v.html
# Привітання від начальника Національного університету оборони України з Днем Повітряних Сил -> u/news/privtannya-vd-nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-dne.html
#  -> u/news/privtannya-vd-nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-dne.html
# Детальніше -> u/news/privtannya-vd-nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-dne.html
# В Національному університету оборони України обговорили модель багаторівневої підготовки з питань доброчесності та запобігання корупції в секторі оборони -> u/news/v-naczonalnomu-unversitetu-oboroni-ukrani-obgovorili-model-bagatorvnev.html
#  -> u/news/v-naczonalnomu-unversitetu-oboroni-ukrani-obgovorili-model-bagatorvnev.html
# Детальніше -> u/news/v-naczonalnomu-unversitetu-oboroni-ukrani-obgovorili-model-bagatorvnev.html
# Національний університет оборони України запустив перший навчальний курс у застосунку “Армія+” – курс “Стоп корупція. Уповноважені” -> u/news/naczonalnij-unversitet-oboroni-ukrani-zapustiv-pershij-navchalnij-kurs.html
#  -> u/news/naczonalnij-unversitet-oboroni-ukrani-zapustiv-pershij-navchalnij-kurs.html
# Детальніше -> u/news/naczonalnij-unversitet-oboroni-ukrani-zapustiv-pershij-navchalnij-kurs.html
# 28 липня — День вшанування пам’яті Захисників та Захисниць України, учасників добровольчих формувань та цивільних осіб, які були страчені, закатовані або загинули у полоні -> u/news/28-lipnya-den-vshanuvannya-pam’yat-zaxisnikv-ta-zaxisnicz-ukrani,-uc.html
#  -> u/news/28-lipnya-den-vshanuvannya-pam’yat-zaxisnikv-ta-zaxisnicz-ukrani,-uc.html
# Детальніше -> u/news/28-lipnya-den-vshanuvannya-pam’yat-zaxisnikv-ta-zaxisnicz-ukrani,-uc.html
# Привітання начальника Національного університету оборони України з Днем медичних працівників -> u/news/privtannya-nachalnika-ukrani-z-dnem-medyka.html
#  -> u/news/privtannya-nachalnika-ukrani-z-dnem-medyka.html
# Детальніше -> u/news/privtannya-nachalnika-ukrani-z-dnem-medyka.html
# «Юстиція військовим»: Мін’юст, Міноборони та Мінветеранів запустили спільний соціальний проєкт для Захисників та Захисниць -> u/news/«yusticzya-vjskovim»-mn’yust,-mnoboroni-ta-mnveteranv-zapustili-sp.html
#  -> u/news/«yusticzya-vjskovim»-mn’yust,-mnoboroni-ta-mnveteranv-zapustili-sp.html
# Детальніше -> u/news/«yusticzya-vjskovim»-mn’yust,-mnoboroni-ta-mnveteranv-zapustili-sp.html
# Привітання Начальника Національного університету оборони України з Днем Української Державності -> u/news/privtannya-nachalnika-naczonalnogo-unversitetu-z-dnem-u.html
#  -> u/news/privtannya-nachalnika-naczonalnogo-unversitetu-z-dnem-u.html
# Детальніше -> u/news/privtannya-nachalnika-naczonalnogo-unversitetu-z-dnem-u.html
# Індивідуальне золото та командна бронза: команда Національного університету оборони України гідно виступила на міжнародних змаганнях у Фінляндії -> u/news/ndivdualne-zoloto-ta-komandna-bronza-komanda-naczonalnogo-unversitet.html
#  -> u/news/ndivdualne-zoloto-ta-komandna-bronza-komanda-naczonalnogo-unversitet.html
# Детальніше -> u/news/ndivdualne-zoloto-ta-komandna-bronza-komanda-naczonalnogo-unversitet.html
# Привітання начальника Національного університету оборони України з Днем Військово-Морських Сил Збройних Сил України -> u/news/vpvkeuk.html
#  -> u/news/vpvkeuk.html
# Детальніше -> u/news/vpvkeuk.html
# Привітання Начальника Національного університету оборони України з Днем армійської авіації СВ ЗС України -> u/news/privtannya-nachalnika-naczonalnogo-dnem-a.html
#  -> u/news/privtannya-nachalnika-naczonalnogo-dnem-a.html
# Детальніше -> u/news/privtannya-nachalnika-naczonalnogo-dnem-a.html
# Привітання начальника Національного університету оборони України з Днем зенітних ракетних військ Повітряних Сил Збройних Сил України -> u/news/privtannya-nachalnika-naczonalnogo-unversitetu.html
#  -> u/news/privtannya-nachalnika-naczonalnogo-unversitetu.html
# Детальніше -> u/news/privtannya-nachalnika-naczonalnogo-unversitetu.html
# З Днем Конституції України! -> u/news/z-dnem-konstitucz-ukrani!.html
#  -> u/news/z-dnem-konstitucz-ukrani!.html
# Детальніше -> u/news/z-dnem-konstitucz-ukrani!.html
# Національний університет оборони України розширює міжнародну співпрацю в сфері доброчесності -> u/news/naczonalnij-unversitet-oboroni-ukrani-rozshiryu-mzhnarodnu-spvpraczyu.html
#  -> u/news/naczonalnij-unversitet-oboroni-ukrani-rozshiryu-mzhnarodnu-spvpraczyu.html
# Детальніше -> u/news/naczonalnij-unversitet-oboroni-ukrani-rozshiryu-mzhnarodnu-spvpraczyu.html
# Представники університету долучились до обговорення уніфікованого плану дій для виконання рекомендацій НАТО щодо доброчесності в секторі безпеки та оборони -> u/news/predstavniki-unversitetu-doluchilis-do-obgovorennya-unfkovanogo-planu.html
#  -> u/news/predstavniki-unversitetu-doluchilis-do-obgovorennya-unfkovanogo-planu.html
# Детальніше -> u/news/predstavniki-unversitetu-doluchilis-do-obgovorennya-unfkovanogo-planu.html
# Привітання начальника Національного університету оборони України з Днем Сил спеціальних операцій ЗС України -> u/news/privtannya-nachalnika-unversitetu-oboroni-ukrani.html
#  -> u/news/privtannya-nachalnika-unversitetu-oboroni-ukrani.html
# Детальніше -> u/news/privtannya-nachalnika-unversitetu-oboroni-ukrani.html
# Привітання начальника Національного університету оборони України з Днем морської піхоти -> u/news/privtannya-nachalnika-unversitetu-oboroni-ukrani-z-dnem-m.html
#  -> u/news/privtannya-nachalnika-unversitetu-oboroni-ukrani-z-dnem-m.html
# Детальніше -> u/news/privtannya-nachalnika-unversitetu-oboroni-ukrani-z-dnem-m.html
# Привітання начальника Національного університету оборони України з Днем науки! -> u/news/privtannya-nachalnika.html
#  -> u/news/privtannya-nachalnika.html
# Детальніше -> u/news/privtannya-nachalnika.html
# Пам'ять живе. Боротьба триває -> u/news/pamyat-zhive.-borotba-triva.html
#  -> u/news/pamyat-zhive.-borotba-triva.html
# Детальніше -> u/news/pamyat-zhive.-borotba-triva.html
# Привітання начальника Національного університету оборони України з Днем піхоти -> u/news/p.html
#  -> u/news/p.html
# Детальніше -> u/news/p.html
# Привітання начальника Національного університету оборони України зі світлим святом Воскресіння Господнього! -> u/news/privtannya-nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-svtlim.html
#  -> u/news/privtannya-nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-svtlim.html
# Детальніше -> u/news/privtannya-nachalnika-naczonalnogo-unversitetu-oboroni-ukrani-z-svtlim.html
# Триває прийом заявок на конкурс прикладних досліджень, спрямованих на посилення обороноздатності та безпеки України -> u/news/triva-prijom-zayavok-na-konkurs-prikladnix-dosldzhen,-spryamovanix-na.html
#  -> u/news/triva-prijom-zayavok-na-konkurs-prikladnix-dosldzhen,-spryamovanix-na.html
# Детальніше -> u/news/triva-prijom-zayavok-na-konkurs-prikladnix-dosldzhen,-spryamovanix-na.html
# Військовослужбовці мають ще один тиждень, щоб своїм голосом вплинути на реформи у Силах оборони. Кожна думка важлива! -> u/news/vjskovosluzhbovcz-mayut-shhe-odin-tizhden,-shhob-svom-golosom-vplinuti.html
#  -> u/news/vjskovosluzhbovcz-mayut-shhe-odin-tizhden,-shhob-svom-golosom-vplinuti.html
# Детальніше -> u/news/vjskovosluzhbovcz-mayut-shhe-odin-tizhden,-shhob-svom-golosom-vplinuti.html
# Провідні науковці та фахівці  НУОУ увійдуть до складу Воєнно-наукової ради МОУ -> u/news/provdn-naukovcz-ta-faxvcz-nuou-uvjdut-do-s-radi-mou.html
#  -> u/news/provdn-naukovcz-ta-faxvcz-nuou-uvjdut-do-s-radi-mou.html
# Детальніше -> u/news/provdn-naukovcz-ta-faxvcz-nuou-uvjdut-do-s-radi-mou.html
# Представники Національного університету оборони України взяли участь в експертному семінарі з виявлення та управління корупційними ризиками в оборонному секторі -> u/news/predstavniki-naczonalnogo-unversitetu-oboroni-ukrani-vzyali-uchast-v-e.html
#  -> u/news/predstavniki-naczonalnogo-unversitetu-oboroni-ukrani-vzyali-uchast-v-e.html
# Детальніше -> u/news/predstavniki-naczonalnogo-unversitetu-oboroni-ukrani-vzyali-uchast-v-e.html
# Національний університет оборони України долучився до розробки сертифікованого курсу «Рівність жінок і чоловіків у Збройних силах України: політика і практика» -> u/news/naczonalnij-unversitet-oboroni-ukrani-doluchivsya-do-rozrobki-sertifko.html
#  -> u/news/naczonalnij-unversitet-oboroni-ukrani-doluchivsya-do-rozrobki-sertifko.html
# Детальніше -> u/news/naczonalnij-unversitet-oboroni-ukrani-doluchivsya-do-rozrobki-sertifko.html
# Представниці Національного університету оборони України долучилися до обговорення інтеграції ґендерних перспектив у військову освіту -> u/news/predstavnicz-naczonalnogo-unversitetu-oboroni-ukranidoluchilisya-do-ob.html
#  -> u/news/predstavnicz-naczonalnogo-unversitetu-oboroni-ukranidoluchilisya-do-ob.html
# Детальніше -> u/news/predstavnicz-naczonalnogo-unversitetu-oboroni-ukranidoluchilisya-do-ob.html
# Відкрита зустріч з експертами НАЗЯВО під час проведення акредитаційної експертизи освітньо-професійної програми першого (бакалаврського) рівня вищої освіти -> u/news/vdkrita-zustrch-z-ekspertami-provedennya-akreditaczjno.html
#  -> u/news/vdkrita-zustrch-z-ekspertami-provedennya-akreditaczjno.html
# Детальніше -> u/news/vdkrita-zustrch-z-ekspertami-provedennya-akreditaczjno.html
# День українського добровольця – день незламних! -> u/news/den-ukranskogo-dobrovolczya-–-den-nezlamnix!.html
#  -> u/news/den-ukranskogo-dobrovolczya-–-den-nezlamnix!.html
# Детальніше -> u/news/den-ukranskogo-dobrovolczya-–-den-nezlamnix!.html
# Освітньо-професійна програма першого (бакалаврського) рівня вищої освіти ступеня бакалавр за спеціальністю 017 "Фізична культура і спорт" -> u/news/news-25-10-03-1.html
#  -> u/news/news-25-10-03-1.html
# Детальніше -> u/news/news-25-10-03-1.html
# 8 Березня – Міжнародний день боротьби за права жінок і міжнародний мир -> u/news/8-bereznya-–-mzhnarodnij-den-borotbi-za-prava-zhnok-mzhnarodnij-mir.html
#  -> u/news/8-bereznya-–-mzhnarodnij-den-borotbi-za-prava-zhnok-mzhnarodnij-mir.html
# Детальніше -> u/news/8-bereznya-–-mzhnarodnij-den-borotbi-za-prava-zhnok-mzhnarodnij-mir.html
# 26 лютого – День спротиву окупації Автономної Республіки Крим та міста Севастополя -> u/news/26-lyutogo-–-den-sprotivu-okupacz-avtonomno-respublki-krim-ta-msta-s.html
#  -> u/news/26-lyutogo-–-den-sprotivu-okupacz-avtonomno-respublki-krim-ta-msta-s.html
# Детальніше -> u/news/26-lyutogo-–-den-sprotivu-okupacz-avtonomno-respublki-krim-ta-msta-s.html
# Сьогодні – третя річниця початку героїчного спротиву України повномасштабній збройній агресії -> u/news/raonako.html
#  -> u/news/raonako.html
# Детальніше -> u/news/raonako.html
# Національний університет оборони України представив новий освітній серіал на Дія.Освіта: "Стоп Корупція. Уповноважені" -> u/news/unversitet-doluchivsya-do-rozrobki-novogo-osvtnogo-seralu-pro-antikoru.html
#  -> u/news/unversitet-doluchivsya-do-rozrobki-novogo-osvtnogo-seralu-pro-antikoru.html
# Детальніше -> u/news/unversitet-doluchivsya-do-rozrobki-novogo-osvtnogo-seralu-pro-antikoru.html
# Відкрита зустріч з експертами НАЗЯВО під час проведення акредитаційної експертизи освітньо-наукової програми підготовки докторів філософії “Право” -> u/news/vdkrita-zustrch-z-ekspertami-nazyavo-pd-chas-akreditaczjno.html
#  -> u/news/vdkrita-zustrch-z-ekspertami-nazyavo-pd-chas-akreditaczjno.html
# Детальніше -> u/news/vdkrita-zustrch-z-ekspertami-nazyavo-pd-chas-akreditaczjno.html
# Відкрита зустріч з експертами НАЗЯВО під час проведення акредитаційної експертизи освітньо-наукової програми підготовки докторів філософії “Цивільна безпека” -> u/news/vdkrita-zustrch-z-ekspertami-nazyavo-pd-chas-provedennya-akreditaczjno.html
#  -> u/news/vdkrita-zustrch-z-ekspertami-nazyavo-pd-chas-provedennya-akreditaczjno.html
# Детальніше -> u/news/vdkrita-zustrch-z-ekspertami-nazyavo-pd-chas-provedennya-akreditaczjno.html
# У День пам’яті Героїв Крут Президент Володимир Зеленський зустрівся з курсантами й ліцеїстами 18 військових навчальних закладів -> u/news/u-den-pam’yat-gerov-krut-prezident-volodimir-zelenskij-zustrvsya-z-k.html
#  -> u/news/u-den-pam’yat-gerov-krut-prezident-volodimir-zelenskij-zustrvsya-z-k.html
# Детальніше -> u/news/u-den-pam’yat-gerov-krut-prezident-volodimir-zelenskij-zustrvsya-z-k.html
# 29 січня День пам'яті Героїв Крут -> u/news/29-schnya-den-pamyat-gerov-krut.html
#  -> u/news/29-schnya-den-pamyat-gerov-krut.html
# Детальніше -> u/news/29-schnya-den-pamyat-gerov-krut.html
# День Соборності України: музичний подарунок від військового оркестру університету у столичному метро -> u/news/den-sobornost-ukrani-muzichnij-podarunok-vd-vjskovogo-orkestru-u-stoli.html
#  -> u/news/den-sobornost-ukrani-muzichnij-podarunok-vd-vjskovogo-orkestru-u-stoli.html
# Детальніше -> u/news/den-sobornost-ukrani-muzichnij-podarunok-vd-vjskovogo-orkestru-u-stoli.html
# Привітання начальника Національного університету оборони України з Днем Соборності України -> u/news/privtannya-nachalnika-unversitetu-oboroni-ukrani-z-dnem.html
#  -> u/news/privtannya-nachalnika-unversitetu-oboroni-ukrani-z-dnem.html
# Детальніше -> u/news/privtannya-nachalnika-unversitetu-oboroni-ukrani-z-dnem.html
# Команда Національного університету оборони України перемогла в зимовому турнірі “Слава та честь” -> u/news/komanda-naczonalnogo-unversitetu-oboroni-ukrani-peremogla-v-zimovomu-t.html
#  -> u/news/komanda-naczonalnogo-unversitetu-oboroni-ukrani-peremogla-v-zimovomu-t.html
# Детальніше -> u/news/komanda-naczonalnogo-unversitetu-oboroni-ukrani-peremogla-v-zimovomu-t.html
# Привітання начальника Національного університету оборони України з Новим роком -> u/news/privtannya-z-novim-2025-rokom.html
#  -> u/news/privtannya-z-novim-2025-rokom.html
# Детальніше -> u/news/privtannya-z-novim-2025-rokom.html
# 2 -> u/?page=2
# 3 -> u/?page=3
# 4 -> u/?page=4
# 5 -> u/?page=5
#  -> u/?page=2
#  -> u/?page=7
# Акредитація -> u/accreditation.html
# Загальні відомості -> u/zv.html
# Керівництво -> u/ku.html
# Новини -> u/news/
# Статут -> u/statut-unversitetu.html
# Структурні підрозділи -> u/stru/
# Оголошення -> u/ogo/
# Документи -> u/dokumenti/
# Міжнародне співробітництво -> u/ms.html
# Кошторис університету -> u/fin-plan.html
# Фінансова звітність -> u/financial-report.html
# Запобігання корупції -> u/zap-kor.html
# Анонси подій -> u/ap/
# Звіти -> u/zvti.html
# Профспілкова організація -> u/pfso.html
# Державні закупівлі -> u/deza.html
# Робота з громадянами -> u/robota-z-gromadyanami.html
# Очищення влади -> u/o-vladi.html
# Академічна доброчесність -> u/akademchna-dobrochesnst.html
# Музей -> u/stru/others/muzei/
# Опитування -> u/survey.html
# Репозиторій кваліфікаційних робіт -> u/repo-kval-rob.html
# Акредитація -> /u/accreditation.html
# Загальні відомості -> /u/zv.html
# Керівництво -> /u/ku.html
# Новини -> /u/news/
# Статут -> /u/statut-unversitetu.html
# Структурні підрозділи -> /u/stru/
# Оголошення -> /u/ogo/
# Міжнародне співробітництво -> /u/ms.html
# Документи -> /u/dokumenti/
# Кошторис університету -> /u/fin-plan.html
# Запобігання корупції -> /u/zap-kor.html
# Фінансова звітність -> /u/financial-report.html
# Анонси подій -> /u/ap/
# Профспілкова організація -> /u/pfso.html
# Державні закупівлі -> /u/deza.html
# Робота з громадянами -> /u/robota-z-gromadyanami.html
# Очищення влади -> /u/o-vladi.html
# Академічна доброчесність -> /u/akademchna-dobrochesnst.html
# Музей -> /u/stru/others/muzei/
# Опитування -> /u/survey.html
# Репозиторій кваліфікаційних робіт -> /u/repo-kval-rob.html
# Концепція освітньої діяльності -> /osvita/kod.html
# Освітні проєкти -> /osvita/op.html
# Вступникам -> /osvita/vstupnikam.html
# Слухачам -> /osvita/sluxacham.html
# Курсантам -> /osvita/kursantam.html
# Студентам -> /u/stru/centers/kvp/
# Лідерські курси -> /osvita/leadership-courses.html
# Редакційно-видавнича діяльність -> /osvita/rvv.html
# Робота спеціалізованих вчених рад -> /nauka/svr/
# Вступникам до докторантури та ад’юнктури -> /nauka/vda.html
# Докторантам, ад’юнктам -> /nauka/doktorantam-adyunktam.html
# Наукові публікації -> /nauka/npub/
# Конференції та семінари -> /nauka/confi/
# Наукові товариства -> /nauka/ntov.html
# Угоди та меморандуми про співробітництво -> /nauka/memo-cooperation.html
# Рада молодих вчених -> /nauka/rada-molodyh-vchenyh.html
# Освітньо-наукові програми підготовки здобувачів ступеня доктора філософії -> /nauka/osv-nauk-programy.html
# Доступ до наукометричних баз та повнотекстових наукових ресурсів -> /nauka/dostup-do-baz-ta-resursiv.html
# Доступ до Національної електронної науково-інформаційної системи NAUKA -> /nauka/dostup-nat-ele-nau-inf-sys.html
# Контакти -> /kontakti.html
#  -> /
# [email protected] -> /cdn-cgi/l/email-protection

# %% [markdown]
# ### 2. Збір даних з використанням формалізованих документів.

# %% [markdown]
# Збір даних з використанням формалізованих документів є одним із основних методів інформаційно-аналітичного забезпечення (ІАЗ), особливо в умовах військового управління. Формалізовані документи забезпечують структуровану, стандартизовану інформацію, що полегшує її обробку, аналіз та інтеграцію в системи ІАЗ.
#
# ### 1. **Визначення формалізованих документів**
# Формалізовані документи – це документи, які мають чітко визначену структуру, формат та зміст, що відповідає встановленим стандартам або протоколам. Вони часто використовуються в державних установах, армії, наукових та ділових сферах. Формат таких документів може бути як електронний, так і паперовий, з обов’язковим використанням загальноприйнятих схем для обміну даними (наприклад, XML, JSON, CSV).
#
# ### 2. **Типи формалізованих документів**
# - **Оперативні звіти та донесення**: Військові організації використовують стандартизовані форми для передачі інформації про оперативну обстановку, рух військ, виявлення противника, статус ресурсів та інше. Прикладом є стандартні форми НАТО, що полегшують взаємодію між союзниками.
# - **Статистичні та аналітичні звіти**: Ці документи містять числову та аналітичну інформацію про результати операцій, використання ресурсів, витрати та інші ключові показники.
# - **Технічні документи**: Опис систем озброєнь, обладнання, інфраструктурних об’єктів або методологій їх використання. Ці документи можуть бути стандартизовані для полегшення впровадження в різних підрозділах.
# - **Нормативні документи**: Стандарти, інструкції та протоколи, що визначають правила поведінки або процеси, які необхідно дотримуватися у певних ситуаціях.
#
# ### 3. **Інструменти збору даних із формалізованих документів**
# Збір даних з формалізованих документів може відбуватися різними методами:
# - **Оцифрування документів**: Документи в паперовому вигляді можна оцифрувати за допомогою сканерів і технологій оптичного розпізнавання тексту (OCR). Це дозволяє перетворити документи у формат, який можна аналізувати автоматично.
# - **Використання стандартів обміну даними**: Стандартизовані формати, такі як XML, JSON або CSV, полегшують автоматичний збір та обробку даних з документів. Інформаційно-аналітичні системи можуть інтегрувати ці документи та автоматично витягувати ключову інформацію для подальшого аналізу.
# - **Програмне забезпечення для обробки документів**: Існують спеціалізовані програми для автоматизованого збирання даних із формалізованих документів. Наприклад, системи керування документами (DMS) дозволяють автоматизувати процес збору та зберігання документів для їх подальшого використання в аналітиці.
#
# ### 4. **Процес збору даних із формалізованих документів**
# - **Ідентифікація типу документа**: Першим кроком є визначення, який тип документу необхідно зібрати, і яку саме інформацію потрібно отримати. Це можуть бути звіти, таблиці, текстові дані тощо.
# - **Структурований аналіз**: Формалізовані документи мають чітку структуру, що дозволяє використовувати автоматизовані інструменти для витягнення інформації. Наприклад, для документів у форматі XML можна використовувати спеціальні парсери для витягнення даних за відповідними тегами.
# - **Аналіз та інтеграція даних**: Після збору дані підлягають аналізу та інтеграції в інформаційно-аналітичні системи. Це дозволяє створювати агреговані звіти, карти, прогнози або рекомендації для прийняття рішень.
#
# ### 5. **Переваги використання формалізованих документів**
# - **Стандартизація**: Формалізовані документи дозволяють використовувати стандарти для збору та обробки даних, що підвищує їх точність і надійність.
# - **Швидкість обробки**: Оскільки документи мають фіксовану структуру, їх можна обробляти автоматизовано, що значно прискорює процес збору даних.
# - **Інтеграція з іншими системами**: Формалізовані документи легко інтегруються з існуючими інформаційними системами, такими як системи керування базами даних, аналітичні платформи та інші інструменти.
#
# ### 6. **Приклад використання формалізованих документів**
# Уявімо ситуацію, коли необхідно зібрати дані про стан технічного забезпечення підрозділів. Використовуючи стандартизовані форми звітів, військові аналітики можуть швидко отримати структуровані дані від усіх підрозділів, агрегувати їх і створити зведений звіт для командування. Такий процес дозволяє скоротити час на підготовку звітів та знизити ризик помилок під час обробки даних.
#
# ### Висновок
# Збір даних із використанням формалізованих документів є важливою складовою ІАЗ, оскільки забезпечує швидку і точну обробку інформації, необхідної для прийняття рішень. Використання сучасних технологій автоматизації дозволяє зменшити витрати часу та підвищити точність аналітики.
#
# Такий контент дозволить студентам отримати розуміння ключових аспектів збору даних із формалізованих документів та їх роль в інформаційно-аналітичному забезпеченні органів управління військами.

# %% [markdown]
# ### Стандартизовані формати для збору даних: XML, JSON, CSV
#
# **1. XML (Extensible Markup Language)**
# XML — це текстовий формат для представлення структурованої інформації, що часто використовується для обміну даними між різними системами. XML є самодокументованим, оскільки теги вказують на зміст даних.
#
# **Основні риси XML**:
# - **Гнучка структура**: Можна визначати власні теги для різних типів даних.
# - **Самодокументованість**: Дані легко читаються людьми і можуть бути перевірені на правильність.
# - **Використання в системах**: Широко використовується в системах, де потрібно передавати великі обсяги даних у вигляді деревоподібних структур (наприклад, SOAP, RSS).
#
# **Приклад XML**:
# ```xml
# <document>
#     <title>Report</title>
#     <date>2024-10-01</date>
#     <author>John Doe</author>
# </document>
# ```
#
# **2. JSON (JavaScript Object Notation)**
# JSON — це легкий формат обміну даними, що легко читається людьми та обробляється машинами. Він популярний завдяки своїй простоті та підтримці багатьма мовами програмування.
#
# **Основні риси JSON**:
# - **Компактність**: JSON займає менше місця, ніж XML, що робить його зручнішим для веб- та мобільних додатків.
# - **Підтримка структурованих даних**: Можна легко створювати об’єкти та масиви даних.
# - **Простота обробки**: Легко інтегрується з мовами програмування, особливо JavaScript.
#
# **Приклад JSON**:
# ```json
# {
#     "title": "Report",
#     "date": "2024-10-01",
#     "author": "John Doe"
# }
# ```
#
# **3. CSV (Comma-Separated Values)**
# CSV — це простий формат для зберігання табличних даних, де кожен рядок представляє запис, а значення розділені комами або іншими роздільниками (наприклад, крапка з комою або табуляція).
#
# **Основні риси CSV**:
# - **Простота використання**: Легко створювати та відкривати у більшості текстових редакторів або електронних таблиць.
# - **Оптимальний для табличних даних**: Використовується для зберігання базових таблиць і списків.
# - **Широка підтримка**: Підтримується різними програмами для обробки даних, такими як Excel або Google Sheets.
#
# **Приклад CSV**:
# ```csv
# title,date,author
# Report,2024-10-01,John Doe
# ```
#
# ### Використання формалізованих форматів в ІАЗ:
# - **XML** часто використовується для обміну даними між системами, які повинні підтримувати складні, ієрархічні структури, такі як звіти чи розпорядження.
# - **JSON** зручний для передачі даних через API і використовується в системах, що потребують швидкої інтеграції та аналізу даних (наприклад, системи реального часу).
# - **CSV** є оптимальним для роботи з великими обсягами табличних даних (наприклад, для зведених звітів чи статистики).
#
# Використання цих форматів в ІАЗ полегшує обробку даних, підвищує точність аналізу та сприяє інтеграції з іншими інформаційними системами.

# %% [markdown]
# Ось приклад коду на Python для роботи з трьома основними форматами даних: **CSV**, **JSON**, та **XML**.
#
# ### 1. Робота з **CSV**
#
# ```python
# import csv
#
# # Створення CSV-файлу
# with open('data.csv', mode='w', newline='') as file:
#     writer = csv.writer(file)
#     writer.writerow(['title', 'date', 'author'])
#     writer.writerow(['Report', '2024-10-01', 'John Doe'])
#
# # Читання CSV-файлу
# with open('data.csv', mode='r') as file:
#     reader = csv.reader(file)
#     for row in reader:
#         print(row)
# ```
#
# ### 2. Робота з **JSON**
#
# ```python
# import json
#
# # Дані у форматі JSON
# data = {
#     "title": "Report",
#     "date": "2024-10-01",
#     "author": "John Doe"
# }
#
# # Запис у файл JSON
# with open('data.json', 'w') as file:
#     json.dump(data, file, indent=4)
#
# # Читання JSON-файлу
# with open('data.json', 'r') as file:
#     data = json.load(file)
#     print(data)
# ```
#
# ### 3. Робота з **XML**
#
# ```python
# import xml.etree.ElementTree as ET
#
# # Створення XML-структури
# root = ET.Element("document")
# title = ET.SubElement(root, "title")
# title.text = "Report"
# date = ET.SubElement(root, "date")
# date.text = "2024-10-01"
# author = ET.SubElement(root, "author")
# author.text = "John Doe"
#
# # Запис у файл XML
# tree = ET.ElementTree(root)
# tree.write("data.xml")
#
# # Читання XML-файлу
# tree = ET.parse('data.xml')
# root = tree.getroot()
# for elem in root:
#     print(elem.tag, ":", elem.text)
# ```
#
# ### Опис:
# 1. **CSV**: Використовується для запису та читання табличних даних.
# 2. **JSON**: Легко використовується для зберігання структурованих даних і передачі їх через мережу.
# 3. **XML**: Підходить для зберігання даних з ієрархічною структурою.
#
# Ці приклади демонструють, як зберігати та читати дані з файлів різних форматів, що може бути корисним для інтеграції з інформаційними системами.

# %% [markdown]
# Ось приклад коду Google Apps Script для створення Google Форми для формалізованого збору даних:
#
# ### Кроки:
# 1. Відкрийте Google Диск.
# 2. Створіть новий файл скрипта: **New > Google Apps Script**.
# 3. Вставте наступний код у редактор скрипта:
#
# ```javascript
# function createForm() {
#   // Створення нової форми
#   var form = FormApp.create('Formalized Data Collection');
#
#   // Додавання поля для введення тексту
#   form.addTextItem()
#       .setTitle('Full Name')
#       .setRequired(true);
#
#   // Додавання поля для вибору дати
#   form.addDateItem()
#       .setTitle('Date of Submission')
#       .setRequired(true);
#
#   // Додавання поля для вибору з кількох варіантів
#   form.addMultipleChoiceItem()
#       .setTitle('Select Department')
#       .setChoiceValues(['IT', 'HR', 'Finance', 'Operations'])
#       .setRequired(true);
#
#   // Додавання поля для введення числового значення
#   form.addTextItem()
#       .setTitle('Employee ID')
#       .setRequired(true);
#
#   // Додавання текстової області для введення коментарів
#   form.addParagraphTextItem()
#       .setTitle('Additional Comments');
#
#   // Вивести URL форми
#   Logger.log('Form URL: ' + form.getEditUrl());
# }
# ```
#
# ### Опис:
# - **FormApp.create()**: Створює нову форму.
# - **addTextItem()**: Додає текстове поле для введення (наприклад, ім'я).
# - **addDateItem()**: Додає поле для вибору дати.
# - **addMultipleChoiceItem()**: Додає варіант вибору з кількох опцій (наприклад, департамент).
# - **addParagraphTextItem()**: Додає текстову область для введення коментарів.
# - **Logger.log()**: Виводить URL створеної форми в журналі.
#
# ### Як запустити:
# 1. Натисніть "Запуск" (Run) для виконання скрипта.
# 2. Після виконання відкрийте журнал (View > Logs) та скопіюйте URL форми.
#
# Цей приклад створює Google Форму для збору формалізованих даних, яку можна використовувати для автоматизації процесу збору інформації.

# %% [markdown]
# Ось приклад коду на Python для збору даних з формалізованої таблиці Excel за допомогою бібліотеки **`pandas`**:
#
# ### Кроки:
# 1. Встановіть бібліотеку `pandas` (якщо ще не встановлена):
#    ```bash
#    pip install pandas openpyxl
#    ```
#
# 2. Використовуйте наступний код для читання даних із файлу Excel:
#
# ```python
# import pandas as pd
#
# # Читання Excel-файлу
# file_path = 'data.xlsx'  # Вкажіть шлях до файлу
# df = pd.read_excel(file_path, sheet_name='Sheet1')  # Задайте ім'я аркуша, якщо він відомий
#
# # Виведення першого рядка таблиці
# print(df.head())
#
# # Збір конкретних даних (наприклад, стовпці 'Name' та 'Date')
# name_column = df['Name']  # Стовпець із іменами
# date_column = df['Date']  # Стовпець із датами
#
# # Виведення зібраних даних
# print('Names:', name_column.tolist())
# print('Dates:', date_column.tolist())
#
# # Приклад обробки: фільтрація за датою
# filtered_data = df[df['Date'] > '2024-01-01']
# print(filtered_data)
# ```
#
# ### Опис:
# 1. **`pd.read_excel()`**: Використовується для читання даних з Excel-файлу. Аргумент `sheet_name` дозволяє вказати конкретний аркуш, з якого ви хочете зібрати дані.
# 2. **`df.head()`**: Виводить перші кілька рядків таблиці для швидкого перегляду структури даних.
# 3. **Фільтрація**: Приклад фільтрації даних за датою — збираються лише записи, де дата більше зазначеної.
#
# ### Вимоги:
# - Формалізована таблиця Excel повинна містити відповідні заголовки стовпців, такі як **'Name'** та **'Date'**, або ви можете змінити назви на ті, що відповідають вашому файлу.
#
# Цей код дозволяє збирати, обробляти та аналізувати дані з таблиці Excel в Python, що може бути корисним для автоматизації збору даних з формалізованих документів.
