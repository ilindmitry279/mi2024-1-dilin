# %% [markdown]
# Приклади роботи з chatGPT:  https://chatgpt.com/share/66f65cf8-a174-8013-87e8-015c468dafab
#                            https://chatgpt.com/share/68b53f42-ae34-8013-923d-dbe2c27c2379
#
# Ось п’ять варіантів задач для практичного заняття, кожен з яких передбачає розробку дуже простої інформаційної системи (ІС) з однією таблицею бази даних, що містить три поля.
#
# ### Варіант 1: Облік книг у бібліотеці
# #### Завдання:
# 1. **Проектування бази даних**:
#    - Таблиця `books` з полями:
#      - `book_id`: унікальний ідентифікатор книги (SERIAL).
#      - `title`: назва книги (VARCHAR).
#      - `author`: автор книги (VARCHAR).
#
# 2. **Розробка REST API**:
#    - `GET /api/books`: отримати всі книги.
#    - `POST /api/books`: додати нову книгу.
#    - `DELETE /api/books/<book_id>`: видалити книгу за `book_id`.
#
# 3. **Розробка простого UI**:
#    - Веб-сторінка для відображення книг.
#    - Форма для додавання нової книги.
#    - Функціонал для видалення книги.
#
# ### Варіант 2: Облік студентів у навчальному закладі
# #### Завдання:
# 1. **Проектування бази даних**:
#    - Таблиця `students` з полями:
#      - `student_id`: унікальний ідентифікатор студента (SERIAL).
#      - `name`: ім'я студента (VARCHAR).
#      - `enrollment_date`: дата зарахування (DATE).
#
# 2. **Розробка REST API**:
#    - `GET /api/students`: отримати всіх студентів.
#    - `POST /api/students`: додати нового студента.
#    - `DELETE /api/students/<student_id>`: видалити студента за `student_id`.
#
# 3. **Розробка простого UI**:
#    - Веб-сторінка для відображення студентів.
#    - Форма для додавання нового студента.
#    - Функціонал для видалення студента.
#
# ### Варіант 3: Облік товарів на складі
# #### Завдання:
# 1. **Проектування бази даних**:
#    - Таблиця `products` з полями:
#      - `product_id`: унікальний ідентифікатор товару (SERIAL).
#      - `product_name`: назва товару (VARCHAR).
#      - `quantity`: кількість на складі (INTEGER).
#
# 2. **Розробка REST API**:
#    - `GET /api/products`: отримати всі товари.
#    - `POST /api/products`: додати новий товар.
#    - `DELETE /api/products/<product_id>`: видалити товар за `product_id`.
#
# 3. **Розробка простого UI**:
#    - Веб-сторінка для відображення товарів.
#    - Форма для додавання нового товару.
#    - Функціонал для видалення товару.
#
# ### Варіант 4: Облік завдань у списку справ
# #### Завдання:
# 1. **Проектування бази даних**:
#    - Таблиця `tasks` з полями:
#      - `task_id`: унікальний ідентифікатор завдання (SERIAL).
#      - `task_name`: назва завдання (VARCHAR).
#      - `due_date`: дата виконання (DATE).
#
# 2. **Розробка REST API**:
#    - `GET /api/tasks`: отримати всі завдання.
#    - `POST /api/tasks`: додати нове завдання.
#    - `DELETE /api/tasks/<task_id>`: видалити завдання за `task_id`.
#
# 3. **Розробка простого UI**:
#    - Веб-сторінка для відображення завдань.
#    - Форма для додавання нового завдання.
#    - Функціонал для видалення завдання.
#
# ### Варіант 5: Облік контактів
# #### Завдання:
# 1. **Проектування бази даних**:
#    - Таблиця `contacts` з полями:
#      - `contact_id`: унікальний ідентифікатор контакту (SERIAL).
#      - `name`: ім'я контакту (VARCHAR).
#      - `phone_number`: номер телефону (VARCHAR).
#
# 2. **Розробка REST API**:
#    - `GET /api/contacts`: отримати всі контакти.
#    - `POST /api/contacts`: додати новий контакт.
#    - `DELETE /api/contacts/<contact_id>`: видалити контакт за `contact_id`.
#
# 3. **Розробка простого UI**:
#    - Веб-сторінка для відображення контактів.
#    - Форма для додавання нового контакту.
#    - Функціонал для видалення контакту.
#
# Варіант 6: Облік вхідних документів
# Завдання:
#
# Проектування бази даних:
#
# Таблиця incoming_docs з полями:
#
# doc_id: унікальний ідентифікатор (SERIAL).
#
# doc_title: назва документа (VARCHAR).
#
# received_date: дата надходження (DATE).
#
# Розробка REST API:
#
# GET /api/incoming_docs: отримати всі записи.
#
# POST /api/incoming_docs: додати запис.
#
# DELETE /api/incoming_docs/<doc_id>: видалити запис.
#
# Розробка простого UI:
#
# Таблиця з переліком документів.
#
# Форма додавання нового документа.
#
# Кнопка видалення запису.
#
# Варіант 7: Облік техніки на ремонті
# Завдання:
#
# Проектування бази даних:
#
# Таблиця repairs з полями:
#
# repair_id: унікальний ідентифікатор (SERIAL).
#
# equipment_name: назва техніки (VARCHAR).
#
# status: стан ремонту (VARCHAR) (напр., "Прийнято", "В роботі", "Готово").
#
# Розробка REST API:
#
# GET /api/repairs: отримати всі записи.
#
# POST /api/repairs: додати запис.
#
# DELETE /api/repairs/<repair_id>: видалити запис.
#
# Розробка простого UI:
#
# Перелік техніки зі статусом.
#
# Форма додавання (назва, статус).
#
# Видалення записів.
#
# Варіант 8: Облік витрат
# Завдання:
#
# Проектування бази даних:
#
# Таблиця expenses з полями:
#
# expense_id: унікальний ідентифікатор (SERIAL).
#
# category: категорія витрати (VARCHAR).
#
# amount: сума (NUMERIC).
#
# Розробка REST API:
#
# GET /api/expenses: отримати всі витрати.
#
# POST /api/expenses: додати витрату.
#
# DELETE /api/expenses/<expense_id>: видалити витрату.
#
# Розробка простого UI:
#
# Таблиця витрат (категорія, сума).
#
# Форма додавання витрати.
#
# Видалення записів.
#
# Нагадування: усе зберігаємо в окремій папці practice5 вашого репозиторію.
#
# ### Загальні вимоги для всіх варіантів:
# - Використання PostgreSQL для бази даних.
# - Розробка REST API за допомогою Flask.
# - Створення простого користувацького інтерфейсу з HTML, CSS і JavaScript.
# - Створити окрему папку для проекту в існуючому репозиторії GitHub, з назвою practice5.
#
# ### Очікувані результати:
# Слухачі повинні вміти створювати просту ІС з базою даних, розробляти REST API та реалізувати базовий веб-інтерфейс для взаємодії з даними, обравши один з варіантів.
